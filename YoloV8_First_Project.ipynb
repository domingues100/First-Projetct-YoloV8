# %% [markdown]
# <a href="https://colab.research.google.com/github/domingues100/First-Projetct-YoloV8/blob/main/YoloV8_First_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and Train

# %% [markdown]
# Installing Roboflow and Ultralytics

# %%
# !pip install roboflow

# %%
# !pip install ultralytics

# %% [markdown]
# Download Dataset from roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="y6aq4mUf3SCKJy2KLONE")
project = rf.workspace("mohamed-traore-2ekkp").project("face-detection-mik1i")
version = project.version(18)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.10, to fix: `pip install ultralytics==8.0.196`

# %% [markdown]
# Using Yolo

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml')

# %%
results = model.train(data='/content/Face-Detection-18/data.yaml', epochs=150)
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Validation métrics

# %%
results = model.val()
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Face-Detection-18/valid/labels.cache... 267 images, 50 backgrounds, 0 corrupt: 100%|██████████| 267/267 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:05<00:00,  3.05it/s]
#                    all        267        506      0.914      0.767      0.873      0.535
# Speed: 0.4ms preprocess, 6.0ms inference, 0.0ms loss, 3.0ms postprocess per image
# Results saved to runs/detect/train62

# %% [markdown]
# # Some Tests in Static Images

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image_file = '/content/394047230.jpg'

image = cv2.imread(image_file)
boxes = model(image)[0].plot()

cv2_imshow(boxes)
# Out:
# 0: 448x640 1 face, 58.8ms
# Speed: 2.3ms preprocess, 58.8ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=2048x1366>

# %% [markdown]
# # Code for Video Inference

# %%
from google.colab.patches import cv2_imshow


video_path = "/content/WhatsApp Video 2024-05-07 at 18.18.56.mp4"
cap = cv2.VideoCapture(video_path)

frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = int(cap.get(cv2.CAP_PROP_FPS))

fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter('output_video.mp4', fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    success, frame = cap.read()

    if success:
        results = model(frame)
        annotated_frame = results[0].plot()
        out.write(annotated_frame)
    else:
        break

cap.release()
out.release()
# Out:
# 0: 640x384 1 face, 103.4ms
# Speed: 2.8ms preprocess, 103.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 10.5ms
# Speed: 2.7ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 12.2ms
# Speed: 2.2ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 12.9ms
# Speed: 2.2ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 face, 12.7ms
# ...
